# %%
import pandas as pd

# %%
import mysql.connector as conn

# %%
drs=pd.read_excel(r'C:\Users\Himanshu Verma\Desktop\fsds_pandas\Dress Sales.xlsx')

# %%
drs
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
att=pd.read_excel(r'C:\Users\Himanshu Verma\Desktop\fsds_pandas\Attribute DataSet.xlsx')

# %%
att
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration PatternType  \
# 0      sleevless    empire            NaN     chiffon     ruffles      animal
# ...

# %%
mydb = conn.connect(host='localhost', user='root', passwd='query', database='sql_task', use_pure=True)

# %%
# question 6
pd.read_sql('select * from attribute as a left join dress_sale as d on(a.Dress_ID=d.Dress_ID);',mydb)
# Out:
# C:\Users\Himanshu Verma\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        Dress_ID    Style      Price  Rating  Size  Season   NeckLine  \
# 0     444282011    party  very-high     4.9     M  Spring     v-neck
# 1     510519284   Casual        Low     4.3  free  Summer   backless
# 2     511503677   Casual        Low     4.4     M  Summer     o-neck
# 3     520233308   Casual        Low     4.7     M  Automn     o-neck
# 4     522776523   Casual        low     4.7  free  Spring     o-neck
# ..          ...      ...        ...     ...   ...     ...        ...
# 470  1246749980  vintage    Average     0.0     S  Spring     o-neck
# 471  1246945687  Novelty    Average     0.0  free  Summer     o-neck
# ...

# %%
# question 7
pd.read_sql('select count(distinct(Dress_ID)) from attribute;',mydb)
# Out:
# C:\Users\Himanshu Verma\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    count(distinct(Dress_ID))
# 0                        475

# %%
# question 8
pd.read_sql('select count(Dress_ID) from attribute where Recommendation=0;',mydb)
# Out:
# C:\Users\Himanshu Verma\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    count(Dress_ID)
# 0              275

# %%
df2=pd.read_sql('select * from dress_sale',mydb)
# Out:
# C:\Users\Himanshu Verma\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# question 9
df2['total_sale']=df2[df2.columns[-23:-1]].sum(axis=1)
df2[['Dress_ID','total_sale']]
# Out:
#        Dress_ID  total_sale
# 0     444282011        1630
# 1     510519284        2684
# 2     511503677       11602
# 3     520233308       10223
# 4     522776523        8798
# ..          ...         ...
# 470  1246749980        5627
# 471  1246945687         967
# 472  1249825438        1697
# 473  1250787559          38
# 474  1253973206        2231
#
# [475 rows x 2 columns]

# %%
# question 10
df2[['Dress_ID','total_sale']].sort_values('total_sale').iloc[-3]
# Out:
# Dress_ID      1006032852
# total_sale         71931
# Name: 327, dtype: int64
